# %%
import nanomotif as nm
import logging as log
log.getLogger().setLevel(log.DEBUG)
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
padding = 12

# %% [markdown]
# # Intro
#
# Documentation of considerations in the implementation of the candidate selection.
#
# The selection is based on the sequences around methylation sites on the contig. At each methylated position, a frame of n posiion on each side of the methylation side is extracted and the index within this subsequence is considered relative to the methylation position (range: -n to n or 0:n*2).
#
# The initial approach for candidate selection is outlined here:
#
# 1. Sample random sequences in contig at canonical bases (e.g. A when 6mA i evaluated)
# 2. Calculate [PSSM](https://cs.rice.edu/~ogilvie/comp571/pssm/) (positional frequencies of bases) for contig sequences
# 3. Extract sequences in contig at all methylation sites
# 4. Set motif candidate to canonical base
# 2. While len(methylations sequences) > minimum sequences
#     - calculate PSSM for methylations sequences
#     - Calculate KL-divergence from methylation PSSM to contig PSSM at each position
#     - Select position in sequence with highest distance
#     - Select most frequent base at this position
#     - Add base to motif
#     - Score new motif
#     - if score > threshold
#         - remove seuqences with motif from methylation sequences
#         - keep motif
#     - else
#         - select sequences with motif from methylation sequences
#
# This should grow a motif by incorporation the most informative positions and bases first.

# %%
ec_assembly = nm.load_assembly("../data/ecoli/assembly.polished.fasta")
ec_pileup = nm.load_pileup("../data/ecoli/modkit.pileup.bed")

# %%
ec_motifs = nm.evaluate.process_sample(
    ec_assembly, 
    ec_pileup.pileup, 
    min_read_methylation_fraction = 0.7,
    min_kl_divergence = 0.2
)

# %%
ec_motifs_plot = ec_motifs \
    .with_columns([
        pl.col("model").apply(lambda model: model.mean()).alias("mean"),
        pl.col("contig").apply(lambda 
                               contig: f"{contig}, {len(ec_assembly.assembly[contig])/ 1e3:.0f}kB").alias("contig_len"),
    ]).sort("motif", descending = True)
heatmap = sns.heatmap(ec_motifs_plot.to_pandas().pivot(values = "mean", index = "contig_len", columns = "motif"), 
                      cmap = "viridis", square=True, vmin = 0.0, vmax = 1.0, annot = True);
heatmap.set_facecolor('lightgray');
plt.title("Mean methylation of identified motifs in E. coli");
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=90);

# %% [markdown]
# # M. ruber

# %%
mr_assembly = nm.load_assembly("../data/mruber/assembly.polished.fasta")
mr_pileup = nm.load_pileup("../data/mruber/modkit.pileup.bed")

# %%
mr_motifs = nm.evaluate.process_sample(mr_assembly, mr_pileup.pileup.filter(pl.col("mod_type")=="a"), 
    min_read_methylation_fraction = 0.80,
    min_kl_divergence = 0.2
    )

# %%
mr_motifs_plot = mr_motifs \
    .with_columns([
        pl.col("model").apply(lambda model: model.mean()).alias("mean"),
        pl.col("contig").apply(lambda contig: f"{contig}, {len(mr_assembly.assembly[contig])/ 1e3:.0f}kB").alias("contig_len"),
    ]).sort("motif", descending = True)
cmap = sns.cubehelix_palette(as_cmap=True, light=.9)
heatmap = sns.heatmap(mr_motifs_plot.to_pandas().pivot(values = "mean", index = "contig_len", columns = "motif"), 
                      cmap = "viridis", square=True, vmin = 0, vmax = 1, annot = True);
heatmap.set_facecolor('lightgray');
plt.title("Mean methylation of identified motifs in M. ruber");

# %% [markdown]
# # Geobacillus

# %%
gb_assembly = nm.load_assembly("../data/geobacillus/assembly.polished.fasta")
gb_pileup = nm.load_pileup("../data/geobacillus/modkit.pileup.bed")

# %%
gb_motifs = nm.evaluate.process_sample(
    gb_assembly, 
    gb_pileup.pileup.filter(pl.col("mod_type") == "a"), 
    max_candidate_size = 30, 
    min_valid_coverage=5,
    min_kl_divergence=0.2, 
    min_read_methylation_fraction = 0.8
    )
# Out:
# INFO: Processing contig_3
# INFO: Processing a
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=807, beta=45886) | 0.06 | 0
# DEBUG: ...............A.C............. | BetaBernoulliModel(alpha=686, beta=8740) | 0.79 | 0
# DEBUG: ..............GA.C............. | BetaBernoulliModel(alpha=603, beta=1453) | 2.36 | 0
# DEBUG: ..............GATC............. | BetaBernoulliModel(alpha=603, beta=106) | 4.62 | 0
# INFO: ..............GATC............., 602 seqs. model: BetaBernoulliModel(alpha=603, beta=106). (25.8 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=807, beta=45886) | 0.06 | 0
# DEBUG: ..............CA............... | BetaBernoulliModel(alpha=52, beta=10001) | 0.00 | 2
# DEBUG: .............CCA............... | BetaBernoulliModel(alpha=48, beta=2509) | 0.18 | 2
# DEBUG: ............CCCA............... | BetaBernoulliModel(alpha=48, beta=354) | 1.36 | 2
# DEBUG: ...........ACCCA............... | BetaBernoulliModel(alpha=48, beta=18) | 5.60 | 2
# DEBUG: ...........ACCCA...........C... | BetaBernoulliModel(alpha=17, beta=4) | 0.97 | 4
# DEBUG: ..A........ACCCA...........C..., Skipping due to length
# DEBUG: ..[AT]........ACCCA...........C..., Skipping due to length
# DEBUG: ...........ACCCA...........[AC]..., Skipping due to length
# DEBUG: ..............AA............... | BetaBernoulliModel(alpha=108, beta=12202) | 0.01 | 3
# DEBUG: ..............AA[TG].............. | BetaBernoulliModel(alpha=149, beta=7597) | 0.12 | 5
# DEBUG: .............[AG]AA[TG].............. | BetaBernoulliModel(alpha=140, beta=4552) | 0.12 | 7
# DEBUG: ...........[AC].[AG]AA[TG].............. | BetaBernoulliModel(alpha=120, beta=2303) | 0.19 | 9
# DEBUG: ...........[AC]C[AG]AA[TG].............. | BetaBernoulliModel(alpha=86, beta=381) | 1.20 | 9
# DEBUG: ...........C.[AG]AA[TG].............. | BetaBernoulliModel(alpha=78, beta=847) | 0.49 | 8
# DEBUG: ...........CC[AG]AA[TG].............. | BetaBernoulliModel(alpha=78, beta=156) | 1.99 | 8
# DEBUG: ..............AAT.............. | BetaBernoulliModel(alpha=79, beta=4266) | 0.10 | 10
# DEBUG: ...........C..AAT.............. | BetaBernoulliModel(alpha=78, beta=726) | 1.03 | 10
# DEBUG: ...........CC.AAT.............. | BetaBernoulliModel(alpha=78, beta=127) | 2.19 | 10
# DEBUG: ...........CCAAAT.............. | BetaBernoulliModel(alpha=78, beta=3) | 4.10 | 10
# DEBUG: ..............AAG.............. | BetaBernoulliModel(alpha=70, beta=3332) | 0.13 | 12
# DEBUG: ..........G...AAG.............. | BetaBernoulliModel(alpha=64, beta=756) | 0.60 | 12
# DEBUG: ..........G..GAAG.............. | BetaBernoulliModel(alpha=65, beta=149) | 1.78 | 12
# DEBUG: ..........G..GAAG[TC]............. | BetaBernoulliModel(alpha=69, beta=53) | 1.42 | 14
# DEBUG: ..........G[AG].GAAG[TC]............. | BetaBernoulliModel(alpha=69, beta=16) | 1.60 | 16
# DEBUG: ..........GA.GAAG[TC]............. | BetaBernoulliModel(alpha=45, beta=7) | 1.76 | 15
# DEBUG: ..........G..GAAGC............. | BetaBernoulliModel(alpha=49, beta=39) | 1.31 | 17
# DEBUG: ..........G[AG].GAAGC............. | BetaBernoulliModel(alpha=49, beta=9) | 1.70 | 19
# DEBUG: ..........GA.GAAGC............. | BetaBernoulliModel(alpha=32, beta=5) | 1.69 | 25
# DEBUG: ..........G..GAAGT............. | BetaBernoulliModel(alpha=20, beta=16) | 1.11 | 27
# DEBUG: ..........G[AG].GAAGT............. | BetaBernoulliModel(alpha=20, beta=8) | 0.99 | 29
# DEBUG: ..........GA.GAAGT............. | BetaBernoulliModel(alpha=13, beta=3) | 1.22 | 29
# DEBUG: ..........GG.GAAGC............. | BetaBernoulliModel(alpha=17, beta=5) | 1.14 | 29
# DEBUG: [TGC].........G[AG].GAAGC............., Skipping due to length
# DEBUG: ........T.G[AG].GAAGT............. | BetaBernoulliModel(alpha=11, beta=2) | 1.02 | 30
# DEBUG: ..........GG.GAAG[TC]............. | BetaBernoulliModel(alpha=24, beta=10) | 0.98 | 30
# DEBUG: .............GAA[TG].............. | BetaBernoulliModel(alpha=62, beta=1662) | 0.16 | 32
# DEBUG: ..........G..GAA[TG].............. | BetaBernoulliModel(alpha=65, beta=375) | 1.08 | 32
# INFO: ...........ACCCA..............., 48 seqs. model: BetaBernoulliModel(alpha=48, beta=18). (19.9 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=807, beta=45886) | 0.06 | 0
# DEBUG: ..............AA............... | BetaBernoulliModel(alpha=108, beta=12202) | 0.01 | 0
# DEBUG: ..............AA[TG].............. | BetaBernoulliModel(alpha=149, beta=7597) | 0.12 | 2
# DEBUG: .............[AG]AA[TG].............. | BetaBernoulliModel(alpha=140, beta=4552) | 0.12 | 4
# DEBUG: ...........[AC].[AG]AA[TG].............. | BetaBernoulliModel(alpha=120, beta=2303) | 0.19 | 6
# DEBUG: ...........[AC]C[AG]AA[TG].............. | BetaBernoulliModel(alpha=86, beta=381) | 1.20 | 6
# DEBUG: ...........C.[AG]AA[TG].............. | BetaBernoulliModel(alpha=78, beta=847) | 0.49 | 5
# DEBUG: ...........CC[AG]AA[TG].............. | BetaBernoulliModel(alpha=78, beta=156) | 1.99 | 5
# DEBUG: ..............AAT.............. | BetaBernoulliModel(alpha=79, beta=4266) | 0.10 | 7
# DEBUG: ............C.AAT.............. | BetaBernoulliModel(alpha=78, beta=844) | 0.80 | 7
# DEBUG: ...........CC.AAT.............. | BetaBernoulliModel(alpha=78, beta=127) | 2.19 | 7
# DEBUG: ...........CCAAAT.............. | BetaBernoulliModel(alpha=78, beta=3) | 4.10 | 7
# DEBUG: ..............AAG.............. | BetaBernoulliModel(alpha=70, beta=3332) | 0.13 | 9
# DEBUG: .............GAAG.............. | BetaBernoulliModel(alpha=62, beta=793) | 0.52 | 9
# DEBUG: ..........G..GAAG.............. | BetaBernoulliModel(alpha=65, beta=149) | 1.78 | 9
# DEBUG: ..........G..GAAG[TC]............. | BetaBernoulliModel(alpha=69, beta=53) | 1.42 | 11
# DEBUG: ..........G[AG].GAAG[TC]............. | BetaBernoulliModel(alpha=69, beta=16) | 1.60 | 13
# DEBUG: ..........GA.GAAG[TC]............. | BetaBernoulliModel(alpha=45, beta=7) | 1.76 | 12
# DEBUG: ..........G..GAAGC............. | BetaBernoulliModel(alpha=49, beta=39) | 1.31 | 14
# DEBUG: ..........G[AG].GAAGC............. | BetaBernoulliModel(alpha=49, beta=9) | 1.70 | 16
# DEBUG: ..........GA.GAAGC............. | BetaBernoulliModel(alpha=32, beta=5) | 1.69 | 22
# DEBUG: ..........G..GAAGT............. | BetaBernoulliModel(alpha=20, beta=16) | 1.11 | 24
# DEBUG: ..........G[AG].GAAGT............. | BetaBernoulliModel(alpha=20, beta=8) | 0.99 | 26
# DEBUG: ..........GA.GAAGT............. | BetaBernoulliModel(alpha=13, beta=3) | 1.22 | 26
# DEBUG: ..........GG.GAAGC............. | BetaBernoulliModel(alpha=17, beta=5) | 1.14 | 28
# DEBUG: [TGC].........G[AG].GAAGC............., Skipping due to length
# DEBUG: ........T.G[AG].GAAGT............. | BetaBernoulliModel(alpha=11, beta=2) | 1.02 | 29
# DEBUG: ..........GG.GAAG[TC]............. | BetaBernoulliModel(alpha=24, beta=10) | 0.98 | 29
# DEBUG: .............GAA[TG].............. | BetaBernoulliModel(alpha=62, beta=1662) | 0.16 | 31
# DEBUG: ..........G..GAA[TG].............. | BetaBernoulliModel(alpha=65, beta=375) | 1.08 | 31
# DEBUG: ..........G..GAA[TG][TC]............. | BetaBernoulliModel(alpha=69, beta=169) | 0.87 | 33
# DEBUG: ..........G[AG].GAA[TG][TC]............. | BetaBernoulliModel(alpha=69, beta=91) | 0.90 | 35
# DEBUG: ..........G..GAA[TG]C............. | BetaBernoulliModel(alpha=49, beta=91) | 1.16 | 34
# DEBUG: ..........G[AG].GAA[TG]C............. | BetaBernoulliModel(alpha=49, beta=39) | 1.13 | 36
# DEBUG: ..........GA.GAA[TG]C............. | BetaBernoulliModel(alpha=32, beta=15) | 1.55 | 42
# DEBUG: [TGC].........G[AG].GAA[TG]C............., Skipping due to length
# DEBUG: ..........GA.GAA[TG][TC]............. | BetaBernoulliModel(alpha=45, beta=44) | 1.13 | 43
# DEBUG: G.........G[AG].GAA[TG]C............., Skipping due to length
# DEBUG: .........[GC]GA.GAA[TG]C............. | BetaBernoulliModel(alpha=22, beta=6) | 1.01 | 44
# DEBUG: ....[AG]....[GC]GA.GAA[TG]C............., Skipping due to length
# DEBUG: ....A....[GC]GA.GAA[TG]C............., Skipping due to length
# DEBUG: [GC].........G[AG].GAA[TG]C............., Skipping due to length
# DEBUG: ...........CC[AG]AA[TG].............[AG], Skipping due to length
# DEBUG: C.........G[AG].GAA[TG]C............., Skipping due to length
# DEBUG: ..........GG.GAAGC...T......... | BetaBernoulliModel(alpha=5, beta=1) | 0.76 | 41
# DEBUG: ..........GG.GAAGC...[AT]......... | BetaBernoulliModel(alpha=13, beta=3) | 0.87 | 41
# DEBUG: .....[GC]....GG.GAAGC...[AT]........., Skipping due to length
# DEBUG: .........CGA.GAAGC............. | BetaBernoulliModel(alpha=9, beta=1) | 0.98 | 42
# DEBUG: .........CGA.GAA[TG]C............. | BetaBernoulliModel(alpha=9, beta=3) | 0.76 | 42
# DEBUG: ..........G..GAA[TG]T............. | BetaBernoulliModel(alpha=20, beta=80) | 0.38 | 42
# INFO: ...........CCAAAT.............., 78 seqs. model: BetaBernoulliModel(alpha=78, beta=3). (10.2 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=807, beta=45886) | 0.06 | 0
# DEBUG: ..........G....A............... | BetaBernoulliModel(alpha=168, beta=7636) | 0.07 | 0
# DEBUG: ..........G..G.A............... | BetaBernoulliModel(alpha=83, beta=2416) | 0.13 | 0
# DEBUG: ..........G..G.AG.............. | BetaBernoulliModel(alpha=63, beta=471) | 0.78 | 0
# DEBUG: ..........G..GAAG.............. | BetaBernoulliModel(alpha=65, beta=149) | 1.78 | 0
# DEBUG: ..........G..GAAG[TC]............. | BetaBernoulliModel(alpha=69, beta=53) | 1.42 | 2
# DEBUG: ..........G[AG].GAAG[TC]............. | BetaBernoulliModel(alpha=69, beta=16) | 1.60 | 4
# DEBUG: ..........GA.GAAG[TC]............. | BetaBernoulliModel(alpha=45, beta=7) | 1.76 | 3
# DEBUG: ..........G..GAAGC............. | BetaBernoulliModel(alpha=49, beta=39) | 1.31 | 5
# DEBUG: ..........G[AG].GAAGC............. | BetaBernoulliModel(alpha=49, beta=9) | 1.70 | 7
# DEBUG: ..........GA.GAAGC............. | BetaBernoulliModel(alpha=32, beta=5) | 1.69 | 13
# DEBUG: ..........G..GAAGT............. | BetaBernoulliModel(alpha=20, beta=16) | 1.11 | 15
# DEBUG: ..........G[AG].GAAGT............. | BetaBernoulliModel(alpha=20, beta=8) | 0.99 | 17
# DEBUG: ..........GA.GAAGT............. | BetaBernoulliModel(alpha=13, beta=3) | 1.22 | 17
# DEBUG: ..........GG.GAAGC............. | BetaBernoulliModel(alpha=17, beta=5) | 1.14 | 19
# DEBUG: [TGC].........G[AG].GAAGC............., Skipping due to length
# DEBUG: ........T.G[AG].GAAGT............. | BetaBernoulliModel(alpha=11, beta=2) | 1.02 | 20
# DEBUG: ........T.G[AG].GAAGT.......[AC]....., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]............. | BetaBernoulliModel(alpha=24, beta=10) | 0.98 | 21
# DEBUG: ..........GG.GAAGC...T......... | BetaBernoulliModel(alpha=5, beta=1) | 0.76 | 23
# DEBUG: ..........GG.GAAGC...[AT]......... | BetaBernoulliModel(alpha=13, beta=3) | 0.87 | 23
# DEBUG: .....[GC]....GG.GAAGC...[AT]........., Skipping due to length
# DEBUG: .........CGA.GAAGC............. | BetaBernoulliModel(alpha=9, beta=1) | 0.98 | 24
# DEBUG: [AG].........GA.GAAGT............., Skipping due to length
# DEBUG: G.........G[AG].GAAGC............., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]...[AT]......... | BetaBernoulliModel(alpha=19, beta=8) | 0.75 | 24
# DEBUG: ..........GG.GAAG[TC]...[AT]..G......, Skipping due to length
# DEBUG: [GC].........G[AG].GAAGC............., Skipping due to length
# DEBUG: .........[GC]GA.GAAGC............. | BetaBernoulliModel(alpha=22, beta=3) | 1.07 | 24
# DEBUG: ....[AG]....[GC]GA.GAAGC............., Skipping due to length
# DEBUG: .........CGA.GAAG[TC]............. | BetaBernoulliModel(alpha=15, beta=2) | 1.01 | 25
# DEBUG: ....G....[GC]GA.GAAGC............. | BetaBernoulliModel(alpha=9, beta=1) | 0.96 | 25
# DEBUG: ..........GG.GAAG[TC]...[AT]..[TG]......, Skipping due to length
# DEBUG: ......A...GG.GAAGC...T......... | BetaBernoulliModel(alpha=4, beta=1) | 0.60 | 24
# DEBUG: ......A...GG.GAAGC...T...T....., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]...T......... | BetaBernoulliModel(alpha=8, beta=3) | 0.67 | 23
# DEBUG: ......C..CGA.GAAG[TC]............. | BetaBernoulliModel(alpha=9, beta=1) | 0.96 | 23
# DEBUG: .....G....GG.GAAGC...[AT]........., Skipping due to length
# DEBUG: .........CGA.GAAGC.[AG]........... | BetaBernoulliModel(alpha=7, beta=1) | 0.81 | 22
# DEBUG: ....G....[GC]GA.GAAGC.....A......., Skipping due to length
# DEBUG: .........[GC]GA.GAAG[TC]............. | BetaBernoulliModel(alpha=31, beta=5) | 1.07 | 21
# DEBUG: ........[TG][GC]GA.GAAG[TC]............., Skipping due to length
# DEBUG: ........G[GC]GA.GAAG[TC]............. | BetaBernoulliModel(alpha=9, beta=1) | 0.98 | 22
# DEBUG: C.........G[AG].GAAGC............., Skipping due to length
# DEBUG: ........T.G[AG].GAAGT.......A....., Skipping due to length
# DEBUG: ....A....[GC]GA.GAAGC............. | BetaBernoulliModel(alpha=7, beta=1) | 0.83 | 20
# DEBUG: ....A..[TC].[GC]GA.GAAGC............., Skipping due to length
# DEBUG: G.........GA.GAAGT............. | BetaBernoulliModel(alpha=4, beta=1) | 0.62 | 21
# DEBUG: ..........GG.GAAGT............. | BetaBernoulliModel(alpha=7, beta=6) | 0.46 | 21
# DEBUG: ..........GG.GAAGT.....T....... | BetaBernoulliModel(alpha=5, beta=2) | 0.75 | 21
# INFO: ..........G..GAAG.............., 69 seqs. model: BetaBernoulliModel(alpha=65, beta=149). (1.7 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=807, beta=45886) | 0.06 | 0
# DEBUG: ...............A.C............. | BetaBernoulliModel(alpha=686, beta=8740) | 0.79 | 2
# DEBUG: ...............A.[GC]............. | BetaBernoulliModel(alpha=684, beta=16491) | 0.26 | 2
# DEBUG: .......C.......A.C............. | BetaBernoulliModel(alpha=158, beta=1790) | 0.20 | 2
# DEBUG: .......C.......A.[GC]............. | BetaBernoulliModel(alpha=141, beta=3378) | 0.10 | 2
# DEBUG: .......C...G...A.[GC]............. | BetaBernoulliModel(alpha=49, beta=921) | 0.14 | 4
# DEBUG: .......C...G...A.[GC].....C......., Skipping due to length
# DEBUG: .......C...C...A.[GC]............. | BetaBernoulliModel(alpha=43, beta=902) | 0.11 | 3
# DEBUG: ...G...C...C...A.[GC]............. | BetaBernoulliModel(alpha=14, beta=191) | 0.18 | 3
# DEBUG: ...G..GC...C...A.[GC]............. | BetaBernoulliModel(alpha=7, beta=62) | 0.22 | 3
# DEBUG: ...G..GCG..C...A.[GC]............. | BetaBernoulliModel(alpha=4, beta=21) | 0.29 | 3
# DEBUG: ...G..GCG..C...A.[GC]....G........, Skipping due to length
# DEBUG: ......GC.......A.C............. | BetaBernoulliModel(alpha=61, beta=573) | 0.22 | 2
# DEBUG: ...G..GC.......A.C............. | BetaBernoulliModel(alpha=26, beta=128) | 0.45 | 2
# DEBUG: ...G..GC.A.....A.C............. | BetaBernoulliModel(alpha=11, beta=37) | 0.38 | 2
# DEBUG: ...G..GC.A.....A.C.........C..., Skipping due to length
# DEBUG: ...G..GC.A.....A.C.........[GC]..., Skipping due to length
# DEBUG: ...............A.G............. | BetaBernoulliModel(alpha=31, beta=9445) | 0.00 | 2
# DEBUG: ...............A.G........G.... | BetaBernoulliModel(alpha=12, beta=2020) | 0.03 | 2
# DEBUG: ...............A.G.....C..G.... | BetaBernoulliModel(alpha=4, beta=459) | 0.03 | 2
# DEBUG: ......C........A.G.....C..G...., Skipping due to length
# DEBUG: .......C...[GC]...A.[GC]............. | BetaBernoulliModel(alpha=84, beta=1706) | 0.13 | 1
# DEBUG: ......CC...[GC]...A.[GC]............. | BetaBernoulliModel(alpha=19, beta=385) | 0.09 | 3
# DEBUG: ......CC...[GC]...A.[GC].....C......., Skipping due to length
# DEBUG: ......GC...[GC]...A.[GC]............. | BetaBernoulliModel(alpha=32, beta=527) | 0.14 | 2
# DEBUG: ...G..GC...[GC]...A.[GC]............., Skipping due to length
# DEBUG: ...G..GC.A.....A.C.........G..., Skipping due to length
# DEBUG: ......[GC]C...[GC]...A.[GC]............., Skipping due to length
# INFO: ...G..GCG..C...A.[GC]....G........, 2 seqs. model: BetaBernoulliModel(alpha=3, beta=3). (1.5 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=807, beta=45886) | 0.06 | 0
# DEBUG: ...............A.C............. | BetaBernoulliModel(alpha=686, beta=8740) | 0.79 | 2
# DEBUG: ...............A.[GC]............. | BetaBernoulliModel(alpha=684, beta=16491) | 0.26 | 2
# DEBUG: ...............A.[GC]........G.... | BetaBernoulliModel(alpha=149, beta=3360) | 0.11 | 4
# DEBUG: ...............A.[GC]........C.... | BetaBernoulliModel(alpha=123, beta=3416) | 0.08 | 4
# DEBUG: ...........G...A.C............. | BetaBernoulliModel(alpha=179, beta=2015) | 0.20 | 4
# DEBUG: .......C...G...A.C............. | BetaBernoulliModel(alpha=47, beta=441) | 0.21 | 6
# DEBUG: ...............A.[GC]........CC... | BetaBernoulliModel(alpha=39, beta=903) | 0.11 | 6
# DEBUG: ......C........A.[GC]........G...., Skipping due to length
# DEBUG: .......G...G...A.C............. | BetaBernoulliModel(alpha=35, beta=459) | 0.12 | 5
# DEBUG: ....C..G...G...A.C............. | BetaBernoulliModel(alpha=5, beta=88) | 0.07 | 5
# DEBUG: ....C..G...G...A.C..........C.., Skipping due to length
# DEBUG: ...............A.G............. | BetaBernoulliModel(alpha=31, beta=9445) | 0.00 | 4
# DEBUG: ...............A.G........G.... | BetaBernoulliModel(alpha=12, beta=2020) | 0.03 | 4
# DEBUG: ......C........A.G........G...., Skipping due to length
# DEBUG: .......C...G...A.C....C........ | BetaBernoulliModel(alpha=9, beta=114) | 0.09 | 3
# DEBUG: .......C...G...A.C....C......C., Skipping due to length
# DEBUG: ...............A.[GC]........[GC].... | BetaBernoulliModel(alpha=231, beta=5452) | 0.11 | 2
# DEBUG: .......[GC]...G...A.C............. | BetaBernoulliModel(alpha=82, beta=873) | 0.18 | 4
# DEBUG: G......[GC]...G...A.C............., Skipping due to length
# DEBUG: C......[GC]...G...A.C............., Skipping due to length
# DEBUG: [GC]......[GC]...G...A.C............., Skipping due to length
# DEBUG: ...............A.[GC]........CC..T, Skipping due to length
# DEBUG: ..............CA.[GC]........[GC]...., Skipping due to length
# DEBUG: ..............AA.[GC]........[GC]...., Skipping due to length
# DEBUG: ..............[AC]A.[GC]........[GC]...., Skipping due to length
# INFO: ...............A.C............., 3 seqs. model: BetaBernoulliModel(alpha=686, beta=8740). (1.1 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=807, beta=45886) | 0.06 | 0
# DEBUG: ...............A.G............. | BetaBernoulliModel(alpha=31, beta=9445) | 0.00 | 0
# DEBUG: ...............A.G........G.... | BetaBernoulliModel(alpha=12, beta=2020) | 0.03 | 0
# DEBUG: ......C........A.G........G...., Skipping due to length
# INFO: No naive guess found, stopping search
# INFO: Processing contig_2
# INFO: Processing a
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# DEBUG: ...............A.C............. | BetaBernoulliModel(alpha=595, beta=9920) | 0.66 | 0
# DEBUG: ..............GA.C............. | BetaBernoulliModel(alpha=529, beta=1740) | 1.97 | 0
# DEBUG: ..............GATC............. | BetaBernoulliModel(alpha=529, beta=232) | 3.68 | 0
# DEBUG: ..............GATCG............ | BetaBernoulliModel(alpha=219, beta=59) | 1.44 | 0
# INFO: ..............GATC............., 524 seqs. model: BetaBernoulliModel(alpha=529, beta=232). (28.1 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# DEBUG: ..............CA............... | BetaBernoulliModel(alpha=58, beta=10690) | 0.01 | 2
# DEBUG: .............CCA............... | BetaBernoulliModel(alpha=57, beta=2208) | 0.29 | 2
# DEBUG: ............CCCA............... | BetaBernoulliModel(alpha=57, beta=288) | 1.84 | 2
# DEBUG: ...........ACCCA............... | BetaBernoulliModel(alpha=57, beta=36) | 2.95 | 2
# DEBUG: ..............AA............... | BetaBernoulliModel(alpha=101, beta=15286) | 0.01 | 1
# DEBUG: ..............AA[TG].............. | BetaBernoulliModel(alpha=139, beta=9422) | 0.09 | 3
# DEBUG: .............[AG]AA[TG].............. | BetaBernoulliModel(alpha=126, beta=5637) | 0.09 | 5
# DEBUG: ..............AAG.............. | BetaBernoulliModel(alpha=72, beta=4044) | 0.13 | 5
# DEBUG: .............GAAG.............. | BetaBernoulliModel(alpha=61, beta=1036) | 0.38 | 5
# DEBUG: ..........G..GAAG.............. | BetaBernoulliModel(alpha=72, beta=219) | 1.76 | 5
# DEBUG: ..........G..GAAG[TC]............. | BetaBernoulliModel(alpha=72, beta=65) | 1.53 | 7
# DEBUG: ..........G[AG].GAAG[TC]............. | BetaBernoulliModel(alpha=72, beta=21) | 1.56 | 9
# DEBUG: ..........G..GAAGT............. | BetaBernoulliModel(alpha=28, beta=21) | 1.52 | 11
# DEBUG: ..........G[AG].GAAGT............. | BetaBernoulliModel(alpha=28, beta=7) | 1.32 | 13
# DEBUG: ..........GA.GAAGT............. | BetaBernoulliModel(alpha=19, beta=4) | 1.33 | 15
# DEBUG: ..........GA.GAAG[TC]............. | BetaBernoulliModel(alpha=47, beta=14) | 1.44 | 17
# DEBUG: ..........G..[AG]AA[TG].............. | BetaBernoulliModel(alpha=83, beta=1296) | 0.36 | 19
# DEBUG: ..........G..[AG]AA[TG][TC]............. | BetaBernoulliModel(alpha=76, beta=629) | 0.37 | 21
# DEBUG: ..........G[AG].[AG]AA[TG][TC]............., Skipping due to length
# DEBUG: ..........G..GAAGC............. | BetaBernoulliModel(alpha=44, beta=45) | 1.26 | 22
# DEBUG: ..........G[AG].GAAGC............. | BetaBernoulliModel(alpha=44, beta=15) | 1.41 | 24
# DEBUG: ..........GG.GAAGC............. | BetaBernoulliModel(alpha=16, beta=5) | 1.22 | 24
# DEBUG: ..........GG.GAAGC...........A., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]............. | BetaBernoulliModel(alpha=25, beta=8) | 1.24 | 23
# DEBUG: ..........GA.GAAGC............. | BetaBernoulliModel(alpha=28, beta=11) | 1.20 | 23
# DEBUG: ..........GA.GAAGC..........[GC].., Skipping due to length
# DEBUG: ..........GA.GAAGC..........G.., Skipping due to length
# DEBUG: ..........G[AG]TGAAG[TC]............. | BetaBernoulliModel(alpha=24, beta=3) | 1.25 | 23
# DEBUG: ..........G..[AG]AA[TG]C............. | BetaBernoulliModel(alpha=46, beta=303) | 0.50 | 25
# DEBUG: ..........G[AG].[AG]AA[TG]C............. | BetaBernoulliModel(alpha=44, beta=175) | 0.48 | 27
# DEBUG: ..........GA.GAAGT.[TG]........... | BetaBernoulliModel(alpha=17, beta=4) | 0.85 | 27
# DEBUG: ..........GA.GAAGC..........C.., Skipping due to length
# DEBUG: ..........GG.[AG]AA[TG]C............. | BetaBernoulliModel(alpha=16, beta=53) | 0.53 | 28
# DEBUG: ..........GG.[AG]AA[TG]C...........A., Skipping due to length
# DEBUG: ..........GA.GAAGT.[TG]......[AC]...., Skipping due to length
# DEBUG: ..............AAT.............. | BetaBernoulliModel(alpha=67, beta=5379) | 0.07 | 26
# DEBUG: ...........C..AAT.............. | BetaBernoulliModel(alpha=65, beta=890) | 0.79 | 26
# DEBUG: ...........CC.AAT.............. | BetaBernoulliModel(alpha=65, beta=142) | 2.16 | 26
# DEBUG: ...........CCAAAT.............. | BetaBernoulliModel(alpha=65, beta=12) | 3.15 | 26
# DEBUG: .............GAA[TG].............. | BetaBernoulliModel(alpha=61, beta=2131) | 0.13 | 26
# DEBUG: ..........G..GAA[TG].............. | BetaBernoulliModel(alpha=72, beta=485) | 1.11 | 26
# DEBUG: ..........G..GAA[TG][TC]............. | BetaBernoulliModel(alpha=72, beta=231) | 0.70 | 28
# DEBUG: ..........G[AG].GAA[TG][TC]............. | BetaBernoulliModel(alpha=72, beta=119) | 0.87 | 30
# DEBUG: ..........G..GAA[TG]C............. | BetaBernoulliModel(alpha=44, beta=121) | 0.81 | 32
# DEBUG: ..........G[AG].GAA[TG]C............. | BetaBernoulliModel(alpha=44, beta=57) | 0.93 | 34
# DEBUG: ..........GG.GAA[TG]C............. | BetaBernoulliModel(alpha=16, beta=15) | 1.05 | 34
# DEBUG: ..........GG.GAA[TG]C...........A., Skipping due to length
# DEBUG: ..........GG.GAA[TG][TC]............. | BetaBernoulliModel(alpha=25, beta=38) | 0.80 | 33
# DEBUG: ..........GA.GAA[TG][TC]............. | BetaBernoulliModel(alpha=47, beta=82) | 0.77 | 33
# DEBUG: ..........GG.[AG]AA[TG][TC]............. | BetaBernoulliModel(alpha=25, beta=120) | 0.42 | 35
# DEBUG: ..........GG.[AG]AA[TG][TC]............A, Skipping due to length
# DEBUG: ..........GA.GAA[TG]C............. | BetaBernoulliModel(alpha=28, beta=43) | 0.72 | 34
# DEBUG: ..........GA.GAA[TG]C..........[GC].., Skipping due to length
# DEBUG: ..........GA.GAA[TG]C..........C.., Skipping due to length
# DEBUG: ..........GG.GAAGT............. | BetaBernoulliModel(alpha=9, beta=4) | 0.76 | 34
# DEBUG: ..........GG.GAAGT............A, Skipping due to length
# DEBUG: ..........G..GAA[TG]T............. | BetaBernoulliModel(alpha=28, beta=111) | 0.46 | 33
# DEBUG: ..........G[AG].GAA[TG]T............. | BetaBernoulliModel(alpha=28, beta=63) | 0.62 | 35
# DEBUG: ..........GA.GAA[TG]T............. | BetaBernoulliModel(alpha=19, beta=40) | 0.63 | 37
# DEBUG: ..........GA.GAA[TG]T.[TG]........... | BetaBernoulliModel(alpha=17, beta=26) | 0.55 | 39
# DEBUG: ..........GA.GAA[TG]T.[TG]......[AC]...., Skipping due to length
# DEBUG: ..........GA.GAA[TG]T.[TG]......A...., Skipping due to length
# DEBUG: ..........GATGAAG[TC]............. | BetaBernoulliModel(alpha=16, beta=3) | 1.00 | 39
# DEBUG: .[GC]........GATGAAG[TC]............., Skipping due to length
# DEBUG: .[AG]........G[AG].GAA[TG]T............., Skipping due to length
# DEBUG: ..........GA[AT]GAA[TG][TC]............. | BetaBernoulliModel(alpha=37, beta=56) | 0.56 | 39
# DEBUG: ..........GA.GAA[TG]C..........G.., Skipping due to length
# DEBUG: ..........GG.GAA[TG]T............. | BetaBernoulliModel(alpha=9, beta=24) | 0.41 | 38
# DEBUG: ..........GG.GAA[TG]T............A, Skipping due to length
# DEBUG: ..........G[AG]TGAA[TG][TC]............. | BetaBernoulliModel(alpha=24, beta=27) | 0.68 | 37
# DEBUG: C.........G[AG]TGAA[TG][TC]............., Skipping due to length
# DEBUG: [GC].........G[AG]TGAA[TG][TC]............., Skipping due to length
# DEBUG: ..........GG.GAA[TG][TC]............A, Skipping due to length
# DEBUG: ..........GA[AT]GAAG[TC]............. | BetaBernoulliModel(alpha=37, beta=10) | 0.99 | 36
# DEBUG: ........T..CCAAAT.............. | BetaBernoulliModel(alpha=35, beta=4) | 1.26 | 36
# DEBUG: ...[GC]....T..CCAAAT.............. | BetaBernoulliModel(alpha=24, beta=1) | 1.45 | 38
# DEBUG: ...[GC]....T..CCAAAT.........[TC]...., Skipping due to length
# DEBUG: ...G....T..CCAAAT.............. | BetaBernoulliModel(alpha=14, beta=1) | 1.17 | 39
# DEBUG: ...G....TC.CCAAAT.............. | BetaBernoulliModel(alpha=12, beta=1) | 1.05 | 39
# DEBUG: ..[GC]G....TC.CCAAAT.............. | BetaBernoulliModel(alpha=12, beta=1) | 1.06 | 41
# DEBUG: .G........G[AG].GAA[TG]T............., Skipping due to length
# DEBUG: ..........GA.GAA[TG]T.T........... | BetaBernoulliModel(alpha=7, beta=10) | 0.49 | 40
# DEBUG: .G........GA.GAA[TG]T.T..........., Skipping due to length
# DEBUG: ..........GA.[AG]AA[TG]C............. | BetaBernoulliModel(alpha=28, beta=123) | 0.39 | 39
# DEBUG: ..........GA.[AG]AA[TG]C..........C.., Skipping due to length
# DEBUG: ..........GA.[AG]AA[TG]C..........[GC].., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]............A, Skipping due to length
# DEBUG: ..........GA.[AG]AA[TG][TC]............. | BetaBernoulliModel(alpha=47, beta=264) | 0.36 | 38
# INFO: ...........CCAAAT.............., 65 seqs. model: BetaBernoulliModel(alpha=65, beta=12). (19.2 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# DEBUG: .............C.A............... | BetaBernoulliModel(alpha=253, beta=9928) | 0.14 | 2
# DEBUG: ............CC.A............... | BetaBernoulliModel(alpha=86, beta=1793) | 0.20 | 2
# DEBUG: ............CCCA............... | BetaBernoulliModel(alpha=57, beta=288) | 1.84 | 2
# DEBUG: ...........ACCCA............... | BetaBernoulliModel(alpha=57, beta=36) | 2.95 | 2
# DEBUG: .............G.A............... | BetaBernoulliModel(alpha=120, beta=10783) | 0.03 | 1
# DEBUG: .............G.AG.............. | BetaBernoulliModel(alpha=52, beta=2211) | 0.12 | 1
# DEBUG: ..........G..G.AG.............. | BetaBernoulliModel(alpha=64, beta=471) | 1.15 | 1
# DEBUG: ..........G..GAAG.............. | BetaBernoulliModel(alpha=72, beta=219) | 1.76 | 1
# DEBUG: ..........G..GAAG[TC]............. | BetaBernoulliModel(alpha=72, beta=65) | 1.53 | 3
# DEBUG: ..........G[AG].GAAG[TC]............. | BetaBernoulliModel(alpha=72, beta=21) | 1.56 | 5
# DEBUG: ..........G..GAAGT............. | BetaBernoulliModel(alpha=28, beta=21) | 1.52 | 7
# DEBUG: ..........G[AG].GAAGT............. | BetaBernoulliModel(alpha=28, beta=7) | 1.32 | 9
# DEBUG: ..........GA.GAAGT............. | BetaBernoulliModel(alpha=19, beta=4) | 1.33 | 11
# DEBUG: ..........GA.GAAG[TC]............. | BetaBernoulliModel(alpha=47, beta=14) | 1.44 | 13
# DEBUG: ..........G..GAAGC............. | BetaBernoulliModel(alpha=44, beta=45) | 1.26 | 15
# DEBUG: ..........G[AG].GAAGC............. | BetaBernoulliModel(alpha=44, beta=15) | 1.41 | 17
# DEBUG: ..........GG.GAAGC............. | BetaBernoulliModel(alpha=16, beta=5) | 1.22 | 17
# DEBUG: ..........GG.GAAGC...........A., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]............. | BetaBernoulliModel(alpha=25, beta=8) | 1.24 | 16
# DEBUG: ..........GA.GAAGC............. | BetaBernoulliModel(alpha=28, beta=11) | 1.20 | 16
# DEBUG: ..........GA.GAAGC..........[GC].., Skipping due to length
# DEBUG: ..........GA.GAAGC..........G.., Skipping due to length
# DEBUG: ..........G[AG]TGAAG[TC]............. | BetaBernoulliModel(alpha=24, beta=3) | 1.25 | 16
# DEBUG: ..........GA.GAAGT.[TG]........... | BetaBernoulliModel(alpha=17, beta=4) | 0.85 | 18
# DEBUG: ..........GA.GAAGC..........C.., Skipping due to length
# DEBUG: ..........GA.GAAGT.[TG]......[AC]...., Skipping due to length
# DEBUG: ..........GG.GAAGT............. | BetaBernoulliModel(alpha=9, beta=4) | 0.76 | 18
# DEBUG: ..........GG.GAAGT............A, Skipping due to length
# DEBUG: ..........GATGAAG[TC]............. | BetaBernoulliModel(alpha=16, beta=3) | 1.00 | 17
# DEBUG: .[GC]........GATGAAG[TC]............., Skipping due to length
# DEBUG: ..........GA[AT]GAAG[TC]............. | BetaBernoulliModel(alpha=37, beta=10) | 0.99 | 18
# DEBUG: .............[GC].A............... | BetaBernoulliModel(alpha=373, beta=18840) | 0.09 | 18
# DEBUG: [GC].........G[AG]TGAAG[TC]............., Skipping due to length
# DEBUG: ..........G[AG][AT]GAAG[TC]............. | BetaBernoulliModel(alpha=53, beta=14) | 1.06 | 19
# DEBUG: .A........G[AG][AT]GAAG[TC]............., Skipping due to length
# DEBUG: .[AG]........G[AG][AT]GAAG[TC]............., Skipping due to length
# DEBUG: .............[GC]CA............... | BetaBernoulliModel(alpha=57, beta=4270) | 0.02 | 19
# DEBUG: ............C[GC]CA............... | BetaBernoulliModel(alpha=57, beta=688) | 0.89 | 19
# DEBUG: ...........AC[GC]CA............... | BetaBernoulliModel(alpha=57, beta=122) | 1.93 | 19
# DEBUG: .[AG]........G[AG].GAAGT............., Skipping due to length
# DEBUG: C.........G[AG]TGAAG[TC]............., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]...........A., Skipping due to length
# DEBUG: ..........GA.GAAGT.[TG]......C...., Skipping due to length
# DEBUG: .G........G[AG].GAAGT............., Skipping due to length
# DEBUG: .C........GATGAAG[TC]............., Skipping due to length
# DEBUG: ..........GA.GAAGT.T........... | BetaBernoulliModel(alpha=7, beta=2) | 0.65 | 12
# DEBUG: .G........GA.GAAGT.T..........., Skipping due to length
# DEBUG: ..........GAAGAAG[TC]............. | BetaBernoulliModel(alpha=21, beta=8) | 0.74 | 11
# DEBUG: ..........GAAGAAG[TC].G........... | BetaBernoulliModel(alpha=14, beta=3) | 0.98 | 11
# DEBUG: ..........GAAGAAG[TC].G.[AG]......... | BetaBernoulliModel(alpha=14, beta=3) | 0.86 | 13
# INFO: ...........ACCCA..............., 57 seqs. model: BetaBernoulliModel(alpha=57, beta=36). (11.4 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# DEBUG: ..........G....A............... | BetaBernoulliModel(alpha=177, beta=8533) | 0.09 | 0
# DEBUG: ..........G....AG.............. | BetaBernoulliModel(alpha=57, beta=1908) | 0.10 | 0
# DEBUG: ..........G..G.AG.............. | BetaBernoulliModel(alpha=64, beta=471) | 1.15 | 0
# DEBUG: ..........G..GAAG.............. | BetaBernoulliModel(alpha=72, beta=219) | 1.76 | 0
# DEBUG: ..........G..GAAG[TC]............. | BetaBernoulliModel(alpha=72, beta=65) | 1.53 | 2
# DEBUG: ..........G[AG].GAAG[TC]............. | BetaBernoulliModel(alpha=72, beta=21) | 1.56 | 4
# DEBUG: ..........G..GAAGT............. | BetaBernoulliModel(alpha=28, beta=21) | 1.52 | 6
# DEBUG: ..........G[AG].GAAGT............. | BetaBernoulliModel(alpha=28, beta=7) | 1.32 | 8
# DEBUG: ..........GA.GAAGT............. | BetaBernoulliModel(alpha=19, beta=4) | 1.33 | 10
# DEBUG: ..........GA.GAAG[TC]............. | BetaBernoulliModel(alpha=47, beta=14) | 1.44 | 12
# DEBUG: ..........G..GAAGC............. | BetaBernoulliModel(alpha=44, beta=45) | 1.26 | 14
# DEBUG: ..........G[AG].GAAGC............. | BetaBernoulliModel(alpha=44, beta=15) | 1.41 | 16
# DEBUG: ..........GG.GAAGC............. | BetaBernoulliModel(alpha=16, beta=5) | 1.22 | 16
# DEBUG: ..........GG.GAAGC...........A., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]............. | BetaBernoulliModel(alpha=25, beta=8) | 1.24 | 15
# DEBUG: ..........GA.GAAGC............. | BetaBernoulliModel(alpha=28, beta=11) | 1.20 | 15
# DEBUG: ..........GA.GAAGC..........[GC].., Skipping due to length
# DEBUG: ..........GA.GAAGC..........G.., Skipping due to length
# DEBUG: ..........G[AG]TGAAG[TC]............. | BetaBernoulliModel(alpha=24, beta=3) | 1.25 | 15
# DEBUG: ..........GA.GAAGT.[TG]........... | BetaBernoulliModel(alpha=17, beta=4) | 0.85 | 17
# DEBUG: ..........GA.GAAGC..........C.., Skipping due to length
# DEBUG: ..........GG.GAAGT............. | BetaBernoulliModel(alpha=9, beta=4) | 0.76 | 16
# DEBUG: ..........GG.GAAGT............A, Skipping due to length
# DEBUG: ..........GATGAAG[TC]............. | BetaBernoulliModel(alpha=16, beta=3) | 1.00 | 15
# DEBUG: .[GC]........GATGAAG[TC]............., Skipping due to length
# DEBUG: ..........GA[AT]GAAG[TC]............. | BetaBernoulliModel(alpha=37, beta=10) | 0.99 | 16
# DEBUG: [GC].........G[AG]TGAAG[TC]............., Skipping due to length
# DEBUG: ..........G[AG][AT]GAAG[TC]............. | BetaBernoulliModel(alpha=53, beta=14) | 1.06 | 15
# DEBUG: .A........G[AG][AT]GAAG[TC]............., Skipping due to length
# DEBUG: .[AG]........G[AG][AT]GAAG[TC]............., Skipping due to length
# DEBUG: .[AG]........G[AG].GAAGT............., Skipping due to length
# DEBUG: C.........G[AG]TGAAG[TC]............., Skipping due to length
# DEBUG: ..........GG.GAAG[TC]...........A., Skipping due to length
# DEBUG: ..........GA.GAAGT.[TG]......C...., Skipping due to length
# DEBUG: .G........G[AG].GAAGT............., Skipping due to length
# DEBUG: .C........GATGAAG[TC]............., Skipping due to length
# DEBUG: ..........GA.GAAGT.T........... | BetaBernoulliModel(alpha=7, beta=2) | 0.65 | 9
# DEBUG: .G........GA.GAAGT.T..........., Skipping due to length
# DEBUG: ..........GAAGAAG[TC]............. | BetaBernoulliModel(alpha=21, beta=8) | 0.74 | 8
# DEBUG: ..........GAAGAAG[TC].G........... | BetaBernoulliModel(alpha=14, beta=3) | 0.98 | 8
# DEBUG: ..........GAAGAAG[TC].G.[AG]......... | BetaBernoulliModel(alpha=14, beta=3) | 0.86 | 10
# DEBUG: ......[AT]...GAAGAAG[TC].G.[AG]........., Skipping due to length
# DEBUG: ..........GAAGAAG[TC].G.A......... | BetaBernoulliModel(alpha=10, beta=1) | 1.08 | 11
# DEBUG: .[AG]........GAAGAAG[TC].G.A........., Skipping due to length
# DEBUG: ......A...GAAGAAG[TC].G.[AG]........., Skipping due to length
# DEBUG: ..........G[AG]AGAAG[TC]............. | BetaBernoulliModel(alpha=29, beta=12) | 0.75 | 11
# DEBUG: ..........G[AG]AGAAG[TC]...[AG]........., Skipping due to length
# DEBUG: ..........G[AG]AGAAG[TC]...A......... | BetaBernoulliModel(alpha=18, beta=5) | 0.93 | 12
# DEBUG: .[AG]........G[AG]AGAAG[TC]...A........., Skipping due to length
# DEBUG: .A........G[AG]AGAAG[TC]...A........., Skipping due to length
# DEBUG: ..........G[AG]AGAAG[TC]...G......... | BetaBernoulliModel(alpha=8, beta=3) | 0.67 | 12
# DEBUG: ..........G[AG]AGAAG[TC]...G.....A..., Skipping due to length
# DEBUG: ..........G[AG]AGAAGC............. | BetaBernoulliModel(alpha=21, beta=10) | 0.67 | 11
# DEBUG: ..........G[AG]AGAAGC.G........... | BetaBernoulliModel(alpha=13, beta=2) | 1.19 | 11
# DEBUG: ..........G[AG]AGAAGC.G.[AG]......... | BetaBernoulliModel(alpha=13, beta=2) | 0.93 | 13
# DEBUG: ..........G[AG]AGAAGC.G.[AG].[AT]......., Skipping due to length
# DEBUG: ..........G[AG]AGAAGC.G.G......... | BetaBernoulliModel(alpha=6, beta=1) | 0.77 | 14
# INFO: ..........G..GAAG.............., 71 seqs. model: BetaBernoulliModel(alpha=72, beta=219). (1.6 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# DEBUG: ......G........A............... | BetaBernoulliModel(alpha=119, beta=7004) | 0.06 | 0
# DEBUG: ......G.....A..A............... | BetaBernoulliModel(alpha=43, beta=2852) | 0.03 | 0
# DEBUG: ......G.....AC.A............... | BetaBernoulliModel(alpha=14, beta=501) | 0.11 | 0
# DEBUG: .....TG.....AC.A............... | BetaBernoulliModel(alpha=8, beta=143) | 0.18 | 0
# DEBUG: .....TG.....ACAA............... | BetaBernoulliModel(alpha=5, beta=56) | 0.18 | 0
# DEBUG: .....TG.....ACAA..............C, Skipping due to length
# INFO: .....TG.....ACAA..............C, 4 seqs. model: BetaBernoulliModel(alpha=4, beta=13). (1.1 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# DEBUG: ...............A.......T....... | BetaBernoulliModel(alpha=114, beta=9317) | 0.03 | 0
# DEBUG: ...............A.......T...T... | BetaBernoulliModel(alpha=41, beta=3708) | 0.03 | 0
# DEBUG: ...........C...A.......T...T... | BetaBernoulliModel(alpha=21, beta=886) | 0.11 | 2
# DEBUG: ...........[GC]...A.......T...T..., Skipping due to length
# DEBUG: .....C.....C...A.......T...T..., Skipping due to length
# DEBUG: ...........G...A.......T...T... | BetaBernoulliModel(alpha=11, beta=978) | 0.03 | 0
# DEBUG: ......G....G...A.......T...T..., Skipping due to length
# INFO: ......G....G...A.......T...T..., 2 seqs. model: BetaBernoulliModel(alpha=6, beta=215). (0.8 % left)
# INFO: Candidate has low score. 1 of 3 before temination
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# DEBUG: ...............A.........C..... | BetaBernoulliModel(alpha=108, beta=6642) | 0.06 | 0
# DEBUG: .............C.A.........C..... | BetaBernoulliModel(alpha=66, beta=1848) | 0.18 | 0
# DEBUG: C............C.A.........C....., Skipping due to length
# INFO: .............C.A.........C....., 1 seqs. model: BetaBernoulliModel(alpha=66, beta=1848). (0.7 % left)
# INFO: Candidate has low score. 2 of 3 before temination
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=730, beta=56235) | 0.04 | 0
# /user_data/sh/dark-science/nanomotif/nanomotif/seq.py:539: UserWarning: No sequences left after filtering
#   warnings.warn("No sequences left after filtering")
# DEBUG: No more sequences left
# INFO: No naive guess found, stopping search
# INFO: Processing contig_1
# INFO: Processing a
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=31424, beta=2132993) | 0.06 | 0
# DEBUG: ...............A.C............. | BetaBernoulliModel(alpha=26280, beta=418984) | 0.83 | 0
# DEBUG: ..............GA.C............. | BetaBernoulliModel(alpha=23167, beta=66203) | 3.23 | 0
# DEBUG: ..............GATC............. | BetaBernoulliModel(alpha=23157, beta=3280) | 7.97 | 0
# DEBUG: ..............GATCG............ | BetaBernoulliModel(alpha=8590, beta=779) | 2.44 | 2
# DEBUG: .............TGATCG............ | BetaBernoulliModel(alpha=2742, beta=192) | 2.23 | 4
# DEBUG: .............[TC]GATCG............ | BetaBernoulliModel(alpha=5938, beta=432) | 2.37 | 3
# DEBUG: ..............GATC[AG]............ | BetaBernoulliModel(alpha=15645, beta=1772) | 2.43 | 2
# DEBUG: .............TGATC[AG]............ | BetaBernoulliModel(alpha=4875, beta=373) | 2.35 | 4
# DEBUG: .............[TC]GATC[AG]............ | BetaBernoulliModel(alpha=10688, beta=903) | 2.46 | 3
# DEBUG: .............CGATC[AG]............ | BetaBernoulliModel(alpha=5820, beta=550) | 2.28 | 2
# DEBUG: .............CGATCG............ | BetaBernoulliModel(alpha=3199, beta=250) | 2.21 | 1
# DEBUG: ..............GATCA............ | BetaBernoulliModel(alpha=7067, beta=1025) | 2.12 | 0
# DEBUG: .............TGATCA............ | BetaBernoulliModel(alpha=2133, beta=182) | 2.19 | 2
# DEBUG: .............[TC]GATCA............ | BetaBernoulliModel(alpha=4757, beta=491) | 2.25 | 1
# DEBUG: .............CGATCA............ | BetaBernoulliModel(alpha=2624, beta=310) | 2.06 | 0
# INFO: ..............GATC............., 23103 seqs. model: BetaBernoulliModel(alpha=23157, beta=3280). (26.4 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=31424, beta=2132993) | 0.06 | 0
# DEBUG: ..............AA............... | BetaBernoulliModel(alpha=4585, beta=578716) | 0.02 | 0
# DEBUG: ..............AA[TG].............. | BetaBernoulliModel(alpha=5985, beta=352142) | 0.13 | 2
# DEBUG: .............[AG]AA[TG].............. | BetaBernoulliModel(alpha=5529, beta=206741) | 0.14 | 4
# DEBUG: ..........G..[AG]AA[TG].............. | BetaBernoulliModel(alpha=3906, beta=53145) | 0.54 | 4
# DEBUG: ..............AAG.............. | BetaBernoulliModel(alpha=3088, beta=149065) | 0.18 | 4
# DEBUG: ..........G...AAG.............. | BetaBernoulliModel(alpha=2893, beta=36624) | 0.76 | 4
# DEBUG: ..........G..GAAG.............. | BetaBernoulliModel(alpha=2944, beta=9120) | 1.96 | 4
# DEBUG: ..........G..GAAG[TC]............. | BetaBernoulliModel(alpha=3073, beta=3178) | 2.18 | 6
# DEBUG: ..........G[AG].GAAG[TC]............. | BetaBernoulliModel(alpha=3078, beta=594) | 3.17 | 8
# DEBUG: ..........GA.GAAG[TC]............. | BetaBernoulliModel(alpha=2142, beta=353) | 3.23 | 8
# DEBUG: ..........GG.GAAG[TC]............. | BetaBernoulliModel(alpha=936, beta=242) | 2.48 | 8
# DEBUG: ..........G..GAAGT............. | BetaBernoulliModel(alpha=1277, beta=1243) | 2.11 | 7
# DEBUG: ..........G[AG].GAAGT............. | BetaBernoulliModel(alpha=1277, beta=330) | 2.49 | 9
# DEBUG: ..........GA.GAAGT............. | BetaBernoulliModel(alpha=878, beta=196) | 2.54 | 8
# DEBUG: ..........GG.GAAGT............. | BetaBernoulliModel(alpha=399, beta=135) | 1.90 | 8
# DEBUG: ..........G..GAAGC............. | BetaBernoulliModel(alpha=1800, beta=1948) | 1.97 | 7
# DEBUG: ..........G[AG].GAAGC............. | BetaBernoulliModel(alpha=1801, beta=265) | 3.38 | 9
# DEBUG: ..........GA.GAAGC............. | BetaBernoulliModel(alpha=1264, beta=158) | 3.42 | 9
# DEBUG: ..........GG.GAAGC............. | BetaBernoulliModel(alpha=537, beta=108) | 2.65 | 9
# DEBUG: .............GAA[TG].............. | BetaBernoulliModel(alpha=2635, beta=76813) | 0.21 | 8
# DEBUG: ..........G..GAA[TG].............. | BetaBernoulliModel(alpha=2932, beta=19110) | 1.41 | 8
# DEBUG: ..........G..GAA[TG][TC]............. | BetaBernoulliModel(alpha=3064, beta=8522) | 1.26 | 10
# DEBUG: ..........G[AG].GAA[TG][TC]............. | BetaBernoulliModel(alpha=3078, beta=3648) | 1.76 | 12
# DEBUG: ..........G..GAA[TG]C............. | BetaBernoulliModel(alpha=1796, beta=3872) | 1.67 | 12
# DEBUG: ..........G[AG].GAA[TG]C............. | BetaBernoulliModel(alpha=1801, beta=1281) | 2.21 | 14
# DEBUG: ..........GA.GAA[TG]C............. | BetaBernoulliModel(alpha=1264, beta=693) | 2.59 | 14
# DEBUG: ..........GA.GAA[TG][TC]............. | BetaBernoulliModel(alpha=2142, beta=2257) | 1.90 | 14
# DEBUG: ..........GG.GAA[TG]C............. | BetaBernoulliModel(alpha=537, beta=589) | 1.31 | 14
# DEBUG: ..........GG.GAA[TG][TC]............. | BetaBernoulliModel(alpha=936, beta=1392) | 1.22 | 13
# DEBUG: ..............AAT.............. | BetaBernoulliModel(alpha=2897, beta=203078) | 0.09 | 12
# DEBUG: ............C.AAT.............. | BetaBernoulliModel(alpha=2872, beta=37712) | 1.03 | 12
# DEBUG: ...........CC.AAT.............. | BetaBernoulliModel(alpha=2868, beta=4607) | 4.68 | 12
# DEBUG: ...........CCAAAT.............. | BetaBernoulliModel(alpha=2867, beta=318) | 4.80 | 12
# DEBUG: ..........G..GAA[TG]T............. | BetaBernoulliModel(alpha=1275, beta=4666) | 0.79 | 14
# DEBUG: ..........G[AG].GAA[TG]T............. | BetaBernoulliModel(alpha=1277, beta=2368) | 1.20 | 16
# DEBUG: ..........GA.GAA[TG]T............. | BetaBernoulliModel(alpha=878, beta=1565) | 1.21 | 15
# DEBUG: ..........GG.GAA[TG]T............. | BetaBernoulliModel(alpha=399, beta=804) | 0.96 | 15
# DEBUG: ..........[TG]CCAAAT.............. | BetaBernoulliModel(alpha=2022, beta=162) | 2.14 | 14
# DEBUG: ..........GA.[AG]AA[TG].............. | BetaBernoulliModel(alpha=2104, beta=17954) | 0.43 | 13
# DEBUG: ..........GA.[AG]AA[TG][TC]............. | BetaBernoulliModel(alpha=2142, beta=8105) | 1.00 | 15
# DEBUG: ..........GA.[AG]AA[TG]C............. | BetaBernoulliModel(alpha=1264, beta=3561) | 1.44 | 15
# DEBUG: ..........GA.[AG]AA[TG]T............. | BetaBernoulliModel(alpha=878, beta=4545) | 0.57 | 15
# DEBUG: ..........TCCAAAT.............. | BetaBernoulliModel(alpha=997, beta=80) | 2.00 | 15
# DEBUG: ..........GCCAAAT.............. | BetaBernoulliModel(alpha=1025, beta=83) | 2.00 | 14
# DEBUG: .........TGCCAAAT.............. | BetaBernoulliModel(alpha=306, beta=20) | 1.79 | 16
# DEBUG: ..........GA.[AG]AA[TG]TG............ | BetaBernoulliModel(alpha=363, beta=1385) | 0.54 | 15
# DEBUG: ..........G[AG].GAA[TG][TC]G............ | BetaBernoulliModel(alpha=1292, beta=1168) | 1.20 | 14
# DEBUG: ..........GA.[AG]AA[TG][TC]G............ | BetaBernoulliModel(alpha=939, beta=2691) | 0.68 | 13
# DEBUG: ..........GA.GAA[TG]TG............ | BetaBernoulliModel(alpha=363, beta=514) | 0.85 | 12
# DEBUG: .........[TC]GCCAAAT.............. | BetaBernoulliModel(alpha=733, beta=57) | 1.89 | 11
# DEBUG: ..........GA.GAA[TG][TC]G............ | BetaBernoulliModel(alpha=941, beta=791) | 1.17 | 10
# DEBUG: .............AAA[TG].............. | BetaBernoulliModel(alpha=2870, beta=133763) | 0.09 | 9
# DEBUG: ............CAAA[TG].............. | BetaBernoulliModel(alpha=2868, beta=22236) | 1.68 | 9
# DEBUG: ...........CCAAA[TG].............. | BetaBernoulliModel(alpha=2867, beta=2205) | 6.03 | 9
# DEBUG: ..........GA.[AG]AA[TG]CG............ | BetaBernoulliModel(alpha=577, beta=1308) | 0.71 | 11
# DEBUG: ..........G[AG].GAAG[TC]G............ | BetaBernoulliModel(alpha=1293, beta=208) | 1.81 | 10
# DEBUG: ..........TCCAAA[TG].............. | BetaBernoulliModel(alpha=997, beta=703) | 1.17 | 9
# DEBUG: ..........[TG]CCAAA[TG].............. | BetaBernoulliModel(alpha=2022, beta=1564) | 1.17 | 8
# DEBUG: ..........G[AG].GAAGCG............ | BetaBernoulliModel(alpha=798, beta=101) | 1.79 | 7
# DEBUG: ..........G[AG].GAA[TG]CG............ | BetaBernoulliModel(alpha=798, beta=493) | 1.22 | 6
# DEBUG: ..........GA.GAA[TG]CG............ | BetaBernoulliModel(alpha=578, beta=278) | 1.27 | 5
# DEBUG: ..........GA.GAAGCG............ | BetaBernoulliModel(alpha=578, beta=70) | 1.71 | 4
# DEBUG: ..........GCCAAA[TG].............. | BetaBernoulliModel(alpha=1025, beta=863) | 1.01 | 3
# DEBUG: .........[TC]GCCAAA[TG].............. | BetaBernoulliModel(alpha=733, beta=588) | 1.06 | 5
# DEBUG: .........CGCCAAA[TG].............. | BetaBernoulliModel(alpha=427, beta=288) | 1.14 | 4
# DEBUG: .........TGCCAAA[TG].............. | BetaBernoulliModel(alpha=306, beta=301) | 0.79 | 3
# DEBUG: ..........GA.GAAG[TC]G............ | BetaBernoulliModel(alpha=942, beta=162) | 1.67 | 2
# DEBUG: .........CGCCAAAT.............. | BetaBernoulliModel(alpha=427, beta=38) | 1.73 | 1
# DEBUG: ..........GA.GAAGTG............ | BetaBernoulliModel(alpha=364, beta=93) | 1.34 | 0
# INFO: ...........CCAAA[TG].............., 2861 seqs. model: BetaBernoulliModel(alpha=2867, beta=2205). (17.3 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=31424, beta=2132993) | 0.06 | 0
# DEBUG: .............C.A............... | BetaBernoulliModel(alpha=10113, beta=403360) | 0.15 | 2
# DEBUG: ............CC.A............... | BetaBernoulliModel(alpha=3546, beta=79043) | 0.24 | 2
# DEBUG: ............CCCA............... | BetaBernoulliModel(alpha=1837, beta=14314) | 0.78 | 2
# DEBUG: ...........ACCCA............... | BetaBernoulliModel(alpha=1834, beta=769) | 8.94 | 2
# DEBUG: .............[GC].A............... | BetaBernoulliModel(alpha=17311, beta=759459) | 0.13 | 1
# DEBUG: .............G.A............... | BetaBernoulliModel(alpha=7474, beta=447879) | 0.07 | 1
# DEBUG: .............G.AG.............. | BetaBernoulliModel(alpha=2470, beta=88826) | 0.15 | 1
# DEBUG: ..........G..G.AG.............. | BetaBernoulliModel(alpha=2792, beta=23268) | 1.15 | 1
# ...
# DEBUG: ......T.A.TGATCA[TC]CGC........... | BetaBernoulliModel(alpha=3, beta=5) | 0.28 | 6
# DEBUG: ......T.A.TGATCA[TC]CGC........[GC].., Skipping due to length
# DEBUG: ......T.A.TGATCA[TC]CGC........G.., Skipping due to length
# DEBUG: ..........[TC]GATCAT.[TG]............ | BetaBernoulliModel(alpha=57, beta=957) | 0.13 | 6
# DEBUG: ..........[TC]GATCAT.[TG].....[AG]......, Skipping due to length
# DEBUG: ..........[TC]GATCAT.[TG].....G......, Skipping due to length
# DEBUG: ..........[TC]GATCAT.[TG].....A......, Skipping due to length
# DEBUG: .........TTGATCAT.............. | BetaBernoulliModel(alpha=11, beta=258) | 0.07 | 5
# DEBUG: A........TTGATCAT.............. | BetaBernoulliModel(alpha=5, beta=83) | 0.13 | 5
# DEBUG: A..[GC].....TTGATCAT.............., Skipping due to length
# DEBUG: A..G.....TTGATCAT.............. | BetaBernoulliModel(alpha=3, beta=23) | 0.28 | 6
# DEBUG: A..G.....TTGATCAT....G........., Skipping due to length
# DEBUG: A..C.....TTGATCAT.............. | BetaBernoulliModel(alpha=2, beta=16) | 0.25 | 5
# DEBUG: A..C.....TTGATCAT.........G...., Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]TT............ | BetaBernoulliModel(alpha=32, beta=362) | 0.16 | 4
# DEBUG: ....C.....[TC]GATCA[TC]TT............, Skipping due to length
# DEBUG: ..........[TC]GATCA[TC].[TG]............ | BetaBernoulliModel(alpha=107, beta=1458) | 0.15 | 3
# DEBUG: ..........[TC]GATCA[TC][TC][TG]............, Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]C[TG]............ | BetaBernoulliModel(alpha=45, beta=394) | 0.28 | 4
# DEBUG: ..........[TC]GATCA[TC]C[TG]....[TC]......., Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]C[TG]....C......., Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]C[TG]....T......., Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]T[TG]............ | BetaBernoulliModel(alpha=40, beta=526) | 0.14 | 3
# DEBUG: ..........[TC]GATCA[TC]T[TG]......G....., Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]T[TG]......C....., Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]T[TG]......[GC]....., Skipping due to length
# DEBUG: ..........[TC]GATCA[TC]CG.C..T......., Skipping due to length
# DEBUG: ......G...[TC]GATCATTT............ | BetaBernoulliModel(alpha=6, beta=48) | 0.11 | 1
# DEBUG: .....CG...[TC]GATCATTT............ | BetaBernoulliModel(alpha=3, beta=12) | 0.36 | 1
# DEBUG: .....CG...[TC]GATCATTT........G..., Skipping due to length
# DEBUG: ......T.A.TGATCA[TC]CGC........C.., Skipping due to length
# INFO: ..........[TC]GATCAT.G....C......., 5 seqs. model: BetaBernoulliModel(alpha=17, beta=79). (1.1 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=31424, beta=2132993) | 0.06 | 0
# DEBUG: ...........G...A............... | BetaBernoulliModel(alpha=5970, beta=393541) | 0.06 | 0
# DEBUG: ...........G..CA............... | BetaBernoulliModel(alpha=222, beta=93321) | 0.00 | 0
# DEBUG: ...........G.TCA............... | BetaBernoulliModel(alpha=217, beta=25024) | 0.01 | 0
# DEBUG: ...........GATCA............... | BetaBernoulliModel(alpha=212, beta=7880) | 0.22 | 0
# DEBUG: ...........GATCAC.............. | BetaBernoulliModel(alpha=107, beta=1287) | 0.48 | 0
# DEBUG: ..........CGATCAC.............. | BetaBernoulliModel(alpha=73, beta=593) | 0.49 | 0
# DEBUG: .[TC]........CGATCAC.............., Skipping due to length
# DEBUG: .T........CGATCAC.............. | BetaBernoulliModel(alpha=26, beta=157) | 0.29 | 1
# DEBUG: .T........CGATCAC............G., Skipping due to length
# DEBUG: .C........CGATCAC.............. | BetaBernoulliModel(alpha=27, beta=177) | 0.26 | 0
# DEBUG: .C........CGATCAC..........G..., Skipping due to length
# INFO: .C........CGATCAC..........G..., 7 seqs. model: BetaBernoulliModel(alpha=15, beta=36). (1.0 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=31424, beta=2132993) | 0.06 | 0
# DEBUG: ...........C...A............... | BetaBernoulliModel(alpha=7425, beta=374557) | 0.10 | 2
# DEBUG: ...........G...A............... | BetaBernoulliModel(alpha=5970, beta=393541) | 0.06 | 2
# DEBUG: ...........[GC]...A............... | BetaBernoulliModel(alpha=12204, beta=617172) | 0.10 | 2
# DEBUG: ...........G..CA............... | BetaBernoulliModel(alpha=222, beta=93321) | 0.00 | 4
# DEBUG: ...........G.TCA............... | BetaBernoulliModel(alpha=217, beta=25024) | 0.01 | 4
# DEBUG: ...........GATCA............... | BetaBernoulliModel(alpha=212, beta=7880) | 0.22 | 4
# DEBUG: ...........GATCAC.............. | BetaBernoulliModel(alpha=107, beta=1287) | 0.48 | 4
# DEBUG: ..........CGATCAC.............. | BetaBernoulliModel(alpha=73, beta=593) | 0.49 | 4
# DEBUG: ..........CGATCAC.T............ | BetaBernoulliModel(alpha=29, beta=197) | 0.25 | 4
# DEBUG: ..........CGATCAC.T....C....... | BetaBernoulliModel(alpha=14, beta=42) | 0.37 | 4
# DEBUG: ....C.....CGATCAC.T....C......., Skipping due to length
# DEBUG: ...........[GC]G..A............... | BetaBernoulliModel(alpha=3009, beta=224474) | 0.03 | 3
# DEBUG: ........G..[GC]G..A............... | BetaBernoulliModel(alpha=766, beta=53833) | 0.05 | 5
# DEBUG: ........G.T[GC]G..A............... | BetaBernoulliModel(alpha=234, beta=15356) | 0.05 | 5
# DEBUG: ........GAT[GC]G..A............... | BetaBernoulliModel(alpha=104, beta=5612) | 0.06 | 5
# DEBUG: .......CGAT[GC]G..A............... | BetaBernoulliModel(alpha=50, beta=1837) | 0.09 | 5
# DEBUG: .......CGAT[GC]G.TA............... | BetaBernoulliModel(alpha=10, beta=286) | 0.09 | 5
# DEBUG: G......CGAT[GC]G.TA..............., Skipping due to length
# DEBUG: ........A..[GC]G..A............... | BetaBernoulliModel(alpha=790, beta=68881) | 0.03 | 4
# DEBUG: .......GA..[GC]G..A............... | BetaBernoulliModel(alpha=186, beta=16241) | 0.03 | 4
# DEBUG: .......GA.C[GC]G..A............... | BetaBernoulliModel(alpha=52, beta=4010) | 0.04 | 6
# DEBUG: .......GA.C[GC]G..A......C........, Skipping due to length
# DEBUG: .......GA.G[GC]G..A............... | BetaBernoulliModel(alpha=70, beta=4819) | 0.05 | 5
# DEBUG: .......GA.[GC][GC]G..A............... | BetaBernoulliModel(alpha=121, beta=8807) | 0.05 | 5
# DEBUG: ....C..GA.[GC][GC]G..A............... | BetaBernoulliModel(alpha=37, beta=1705) | 0.08 | 7
# DEBUG: ....C..GA.[GC][GC]G..A.........C....., Skipping due to length
# DEBUG: ....[GC]..GA.[GC][GC]G..A..............., Skipping due to length
# DEBUG: ....G..GA.G[GC]G..A............... | BetaBernoulliModel(alpha=24, beta=1410) | 0.05 | 5
# DEBUG: ....G..GA.G[GC]GG.A............... | BetaBernoulliModel(alpha=13, beta=511) | 0.08 | 5
# DEBUG: ....G..GAAG[GC]GG.A............... | BetaBernoulliModel(alpha=8, beta=245) | 0.08 | 5
# DEBUG: ....G..GAAG[GC]GG.A..[GC]............, Skipping due to length
# DEBUG: ....G..GAAG[GC]GG.A..C............ | BetaBernoulliModel(alpha=4, beta=42) | 0.33 | 6
# DEBUG: ....G..GAAG[GC]GG.A..C...........G, Skipping due to length
# DEBUG: ....G..GAAG[GC]GG.A..G............ | BetaBernoulliModel(alpha=3, beta=63) | 0.10 | 5
# DEBUG: ....GA.GAAG[GC]GG.A..G............ | BetaBernoulliModel(alpha=3, beta=31) | 0.23 | 5
# DEBUG: ..T.GA.GAAG[GC]GG.A..G............, Skipping due to length
# DEBUG: ....G..GA.[GC][GC]G..A............... | BetaBernoulliModel(alpha=36, beta=2516) | 0.04 | 4
# DEBUG: ....G..GA.[GC][GC]GG.A............... | BetaBernoulliModel(alpha=14, beta=796) | 0.05 | 4
# DEBUG: ....G..GAA[GC][GC]GG.A............... | BetaBernoulliModel(alpha=8, beta=352) | 0.06 | 4
# DEBUG: ....G..GAA[GC][GC]GG.A..[GC]............, Skipping due to length
# DEBUG: ....G..GAA[GC][GC]GG.A..C............, Skipping due to length
# DEBUG: ....G..GAA[GC][GC]GG.A..G............, Skipping due to length
# DEBUG: ........[AG]..[GC]G..A............... | BetaBernoulliModel(alpha=1453, beta=115154) | 0.04 | 3
# DEBUG: .......G[AG]..[GC]G..A............... | BetaBernoulliModel(alpha=331, beta=26951) | 0.04 | 5
# DEBUG: .......G[AG].C[GC]G..A............... | BetaBernoulliModel(alpha=83, beta=6556) | 0.04 | 7
# DEBUG: .......G[AG].C[GC]G..A.....C........., Skipping due to length
# DEBUG: .......G[AG].G[GC]G..A............... | BetaBernoulliModel(alpha=124, beta=7884) | 0.06 | 6
# DEBUG: .......C[AG]..[GC]G..A............... | BetaBernoulliModel(alpha=440, beta=31199) | 0.05 | 6
# DEBUG: .......C[AG].T[GC]G..A............... | BetaBernoulliModel(alpha=144, beta=8986) | 0.05 | 6
# DEBUG: ....G..G[AG].G[GC]G..A............... | BetaBernoulliModel(alpha=39, beta=2238) | 0.05 | 6
# DEBUG: ....G..G[AG].G[GC]GG.A............... | BetaBernoulliModel(alpha=19, beta=793) | 0.07 | 6
# DEBUG: ....G..G[AG]AG[GC]GG.A............... | BetaBernoulliModel(alpha=11, beta=343) | 0.08 | 6
# DEBUG: ....G..G[AG]AG[GC]GG.A..[GC]............, Skipping due to length
# DEBUG: ....G..G[AG]AG[GC]GG.A..C............, Skipping due to length
# DEBUG: ....G..G[AG]AG[GC]GG.A..G............, Skipping due to length
# DEBUG: .......G[AG].[GC][GC]G..A............... | BetaBernoulliModel(alpha=201, beta=14175) | 0.05 | 5
# DEBUG: ....C..G[AG].[GC][GC]G..A..............., Skipping due to length
# DEBUG: ....G..G[AG].[GC][GC]G..A..............., Skipping due to length
# DEBUG: ....[GC]..G[AG].[GC][GC]G..A..............., Skipping due to length
# DEBUG: .......C[AG]AT[GC]G..A............... | BetaBernoulliModel(alpha=68, beta=3701) | 0.05 | 4
# DEBUG: .......C[AG]AT[GC]G.TA............... | BetaBernoulliModel(alpha=10, beta=609) | 0.03 | 4
# DEBUG: G......C[AG]AT[GC]G.TA..............., Skipping due to length
# DEBUG: .......[GC][AG]..[GC]G..A............... | BetaBernoulliModel(alpha=728, beta=56087) | 0.04 | 3
# DEBUG: .......[GC][AG]..[GC]G..A.G............., Skipping due to length
# DEBUG: ...........[GC]A..A............... | BetaBernoulliModel(alpha=3190, beta=249669) | 0.03 | 2
# DEBUG: ...........[GC]A.CA............... | BetaBernoulliModel(alpha=207, beta=60869) | 0.00 | 2
# DEBUG: ...........[GC]ATCA............... | BetaBernoulliModel(alpha=212, beta=19090) | 0.11 | 2
# DEBUG: ...........[GC]ATCAC.............. | BetaBernoulliModel(alpha=109, beta=3434) | 0.22 | 2
# DEBUG: ..........C[GC]ATCAC.............. | BetaBernoulliModel(alpha=74, beta=1200) | 0.24 | 2
# DEBUG: ..........C[GC]ATCAC.T............ | BetaBernoulliModel(alpha=29, beta=396) | 0.15 | 2
# DEBUG: ..........C[GC]ATCAC.T....C....... | BetaBernoulliModel(alpha=14, beta=107) | 0.30 | 2
# DEBUG: ....C.....C[GC]ATCAC.T....C......., Skipping due to length
# DEBUG: ...........CG..A............... | BetaBernoulliModel(alpha=1403, beta=141441) | 0.02 | 1
# DEBUG: ........G..CG..A............... | BetaBernoulliModel(alpha=305, beta=26800) | 0.04 | 3
# DEBUG: ........GA.CG..A............... | BetaBernoulliModel(alpha=124, beta=8747) | 0.05 | 3
# DEBUG: ........GATCG..A............... | BetaBernoulliModel(alpha=57, beta=2654) | 0.05 | 3
# DEBUG: ........GATCG.TA............... | BetaBernoulliModel(alpha=15, beta=492) | 0.09 | 5
# DEBUG: .......CGATCG.TA............... | BetaBernoulliModel(alpha=10, beta=169) | 0.19 | 5
# DEBUG: G......CGATCG.TA............... | BetaBernoulliModel(alpha=6, beta=44) | 0.35 | 5
# INFO: ..T.GA.GAAG[GC]GG.A..G............, 3 seqs. model: BetaBernoulliModel(alpha=3, beta=5). (1.0 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=31424, beta=2132993) | 0.06 | 0
# DEBUG: ...........G...A............... | BetaBernoulliModel(alpha=5970, beta=393541) | 0.06 | 0
# DEBUG: ...........G..CA............... | BetaBernoulliModel(alpha=222, beta=93321) | 0.00 | 0
# DEBUG: ...........G.TCA............... | BetaBernoulliModel(alpha=217, beta=25024) | 0.01 | 0
# DEBUG: ...........GATCA............... | BetaBernoulliModel(alpha=212, beta=7880) | 0.22 | 0
# DEBUG: ...........GATCAC.............. | BetaBernoulliModel(alpha=107, beta=1287) | 0.48 | 0
# DEBUG: ..........CGATCAC.............. | BetaBernoulliModel(alpha=73, beta=593) | 0.49 | 0
# DEBUG: ..........CGATCAC.T............ | BetaBernoulliModel(alpha=29, beta=197) | 0.25 | 0
# DEBUG: ..........CGATCAC.T....C....... | BetaBernoulliModel(alpha=14, beta=42) | 0.37 | 0
# DEBUG: ....C.....CGATCAC.T....C......., Skipping due to length
# INFO: ....C.....CGATCAC.T....C......., 7 seqs. model: BetaBernoulliModel(alpha=9, beta=17). (1.0 % left)
# INFO: Continuing search
# DEBUG: ...............A............... | BetaBernoulliModel(alpha=31424, beta=2132993) | 0.06 | 0
# DEBUG: ...............A.C............. | BetaBernoulliModel(alpha=26280, beta=418984) | 0.83 | 2
# DEBUG: ...............A.[GC]............. | BetaBernoulliModel(alpha=26556, beta=773514) | 0.28 | 2
# DEBUG: .............T.A.C............. | BetaBernoulliModel(alpha=7132, beta=108334) | 0.20 | 2
# DEBUG: ...........G.T.A.C............. | BetaBernoulliModel(alpha=2131, beta=25026) | 0.28 | 2
# DEBUG: ...........G...A.[GC]............. | BetaBernoulliModel(alpha=5998, beta=191256) | 0.10 | 2
# DEBUG: ...........G.T.A.[GC]............. | BetaBernoulliModel(alpha=2101, beta=50981) | 0.16 | 2
# DEBUG: ...............A.G............. | BetaBernoulliModel(alpha=1229, beta=445742) | 0.00 | 2
# DEBUG: ...............A.G.......C..... | BetaBernoulliModel(alpha=316, beta=94773) | 0.01 | 2
# DEBUG: ...............A.GG......C..... | BetaBernoulliModel(alpha=88, beta=23419) | 0.01 | 4
# DEBUG: ...............A.GG......CC.... | BetaBernoulliModel(alpha=21, beta=5221) | 0.01 | 6
# DEBUG: ...........G...A.GG......CC.... | BetaBernoulliModel(alpha=6, beta=1252) | 0.02 | 6
# DEBUG: .....[GC].....G...A.GG......CC...., Skipping due to length
# DEBUG: .....C.....G...A.GG......CC...., Skipping due to length
# DEBUG: .....G.....G...A.GG......CC...., Skipping due to length
# DEBUG: ...............A.GC......C..... | BetaBernoulliModel(alpha=97, beta=26920) | 0.01 | 5
# DEBUG: ...........C...A.GC......C..... | BetaBernoulliModel(alpha=45, beta=5742) | 0.05 | 7
# DEBUG: ...........[GC]...A.GC......C..... | BetaBernoulliModel(alpha=72, beta=12507) | 0.03 | 7
# DEBUG: ....C......[GC]...A.GC......C....., Skipping due to length
# DEBUG: ....[GC]......[GC]...A.GC......C....., Skipping due to length
# DEBUG: ....G......[GC]...A.GC......C....., Skipping due to length
# DEBUG: ...........G...A.GC......C..... | BetaBernoulliModel(alpha=28, beta=6995) | 0.01 | 6
# DEBUG: ...........G.T.A.GC......C..... | BetaBernoulliModel(alpha=26, beta=1606) | 0.16 | 6
# DEBUG: ........A..G.T.A.GC......C..... | BetaBernoulliModel(alpha=17, beta=452) | 0.17 | 6
# DEBUG: .......GA..G.T.A.GC......C....., Skipping due to length
# DEBUG: ...............A.GG......CG.... | BetaBernoulliModel(alpha=32, beta=7707) | 0.01 | 5
# DEBUG: ...............A.GG...[GC]..CG.... | BetaBernoulliModel(alpha=26, beta=2998) | 0.05 | 7
# DEBUG: ...............A.GG...C..CG.... | BetaBernoulliModel(alpha=18, beta=1452) | 0.09 | 7
# DEBUG: .........G.....A.GG...C..CG.... | BetaBernoulliModel(alpha=14, beta=371) | 0.22 | 7
# DEBUG: .........G.....A.GGC..C..CG.... | BetaBernoulliModel(alpha=12, beta=125) | 0.34 | 7
# DEBUG: ..G......G.....A.GGC..C..CG...., Skipping due to length
# DEBUG: ...............A.GG...[GC]..CGG... | BetaBernoulliModel(alpha=16, beta=738) | 0.12 | 6
# DEBUG: ...............A.GG...[GC]..CGG.T. | BetaBernoulliModel(alpha=13, beta=198) | 0.32 | 6
# DEBUG: .........G.....A.GG...[GC]..CGG.T., Skipping due to length
# DEBUG: ...............A.GG...G..CG.... | BetaBernoulliModel(alpha=8, beta=1554) | 0.02 | 5
# DEBUG: .......G.......A.GG...G..CG...., Skipping due to length
# DEBUG: ...............A.GG......C[GC].... | BetaBernoulliModel(alpha=53, beta=12788) | 0.01 | 4
# DEBUG: .....C.........A.GG......C[GC]...., Skipping due to length
# DEBUG: .....[GC].........A.GG......C[GC]...., Skipping due to length
# DEBUG: .....G.........A.GG......C[GC]...., Skipping due to length
# DEBUG: ...........G.TCA.[GC]............. | BetaBernoulliModel(alpha=140, beta=11891) | 0.01 | 3
# DEBUG: ...........GATCA.[GC]............. | BetaBernoulliModel(alpha=135, beta=3853) | 0.25 | 3
# DEBUG: ...........GATCAC[GC]............. | BetaBernoulliModel(alpha=61, beta=622) | 0.46 | 3
# DEBUG: ........C..GATCAC[GC]............. | BetaBernoulliModel(alpha=18, beta=125) | 0.28 | 5
# INFO: ...............A.C............., 79 seqs. model: BetaBernoulliModel(alpha=26280, beta=418984). (0.8 % left)
# INFO: Stopping search, too few sequences left

# %%
gb_motifs.filter(pl.col("score") > 1)

# %%
log.basicConfig(level=log.INFO);
gb_motifs_plot = gb_motifs.filter(pl.col("score") > 1) \
    .with_columns([
        pl.col("model").apply(lambda model: model.mean()).alias("mean"),
        pl.col("contig").apply(lambda contig: f"{contig}, {len(gb_assembly.assembly[contig])/ 1e3:.0f}kB").alias("contig_len"),
        (pl.col("motif") + pl.col("mod_position").cast(pl.Utf8)).alias("motif_position")
    ]).sort("motif", descending = True)
cmap = sns.cubehelix_palette(as_cmap=True, light=.9)
heatmap = sns.heatmap(gb_motifs_plot.to_pandas().pivot(values = "mean", index = "contig_len", columns = "motif_position"), 
                      cmap = "viridis", square=True, vmin = 0, vmax = 1, annot = True);
heatmap.set_facecolor('lightgray')
plt.title("Mean methylation of identified motifs in Geobacillus");

# %% [markdown]
# # E. coli -dcm/-dam

# %%
ecneg_assembly = nm.load_assembly("../data/ecoli_neg/assembly.polished.fasta")
ecneg_pileup = nm.load_pileup("../data/ecoli_neg/modkit.pileup.bed")

# %%
ecneg_assembly.assembly.keys()

# %%
ecneg_motifs = nm.evaluate.process_sample(ecneg_assembly, ecneg_pileup.pileup, min_read_methylation_fraction = 0)

# %% [markdown]
# # Combining results

# %%
assemblies = {
    "E. coli K12": ec_assembly,
    "E. coli -dam/-dcm": ecneg_assembly,
    "Geobacillus": gb_assembly,
    "M. ruber": mr_assembly
}
pileups = {
    "E. coli K12": ec_pileup,
    "E. coli -dam/-dcm": ecneg_pileup,
    "Geobacillus": gb_pileup,
    "M. ruber": mr_pileup
}

# %%
all_motifs = pl.concat([ec_motifs, mr_motifs, gb_motifs])
all_motifs_scored = {
    "sample":[],
    "contig":[],
    "type":[],
    "motif":[],
    "model":[],
    "mean":[],
    "score":[],
    "contig_length":[],
    "mod_position":[]
}
for sample, assembly in assemblies.items():

    pileup_filt = pileups[sample].pileup.filter(pl.col("Nvalid_cov") > 5) \
        .filter(pl.col("fraction_mod") > 0.80)
    for contig, contig_sequence in assembly.assembly.items():
        print(contig)
        pileup_filt_contig = pileup_filt.filter(pl.col("contig") == contig)
        for row in all_motifs.rows():
            print(row[-2])
            model = nm.evaluate.score_candidate(
                pileup_filt_contig.filter(pl.col("mod_type") == row[-3]),
                contig_sequence.sequence,
                row[-2],
                row[-1]
            )
            all_motifs_scored["sample"].append(sample)
            all_motifs_scored["contig"].append(contig)
            all_motifs_scored["motif"].append(row[-2])
            all_motifs_scored["model"].append(model)
            all_motifs_scored["mean"].append(model.mean())
            all_motifs_scored["score"].append(1 - model.cdf(0.55))
            all_motifs_scored["type"].append(row[-3])
            all_motifs_scored["contig_length"].append(len(contig_sequence.sequence))
            all_motifs_scored["mod_position"].append(row[-1])
all_motifs_scored

# %%
motifs_all_samples = pl.DataFrame(all_motifs_scored) \
.with_columns(
    (pl.col("sample") + "\n" + (pl.col("contig_length")/1e3).cast(pl.Int16).cast(pl.Utf8) + "kb").alias("id"),
    (pl.col("motif") + "_" + pl.col("type")+ "_" + pl.col("mod_position").cast(pl.Utf8)).alias("motif_mod_type")
)
motifs_all_samples

# %%
cmap = sns.cubehelix_palette(as_cmap=True, light=.8)
heatmap = sns.clustermap(
    motifs_all_samples.to_pandas().reset_index().drop_duplicates(subset=['id', 'motif_mod_type'], keep='last').pivot(values = "score", index = "id", columns = "motif_mod_type"), 
    cmap = "viridis", vmin = 0, vmax = 1,
    row_cluster=True, col_cluster=True, dendrogram_ratio=0.15, figsize = (8, 8));
heatmap.ax_heatmap.yaxis.set_ticklabels(heatmap.ax_heatmap.yaxis.get_ticklabels(), rotation=0, ha='left');

# %%
motifs_all_samples

# %%
motifs_all_samples \
        .to_pandas().reset_index().drop_duplicates(subset=['id', 'motif_mod_type'], keep='last') \
        .pivot(values = "mean", index = "id", columns = "motif_mod_type")

# %%
sns.heatmap(
    motifs_all_samples \
        .to_pandas().reset_index().drop_duplicates(subset=['id', 'motif_mod_type'], keep='last') \
        .pivot(values = "mean", index = "id", columns = "motif_mod_type"),
    cmap="viridis",
    annot = True,
    square = True)

# %%
cm_plot = sns.clustermap(
    motifs_all_samples \
        .with_columns(
            pl.col("mean").round(1).alias("mean_rounded")
        )
        .to_pandas().reset_index().drop_duplicates(subset=['id', 'motif_mod_type'], keep='last') \
        .pivot(values = "mean_rounded", index = "id", columns = "motif_mod_type"),
    cmap="viridis",
    tree_kws={"linewidths": 0.},
    cbar_kws={"label": "Degree of methylation"},
    cbar_pos=(0.84, 0.31, 0.014, 0.52),
    vmin=0,
    vmax=1,
    figsize=(10, 6),
    annot=True
    );
cm_plot.ax_heatmap.set_xlabel("motif, type, modifed position")
cm_plot.ax_heatmap.set_ylabel("")
cm_plot.ax_heatmap.yaxis.tick_left()
